# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrook7/Pedrook7/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization - Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index('País', inplace=True)

# %%
anos = list(map(str, range(1980, 2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil', anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
brasil_dict = {'ano': brasil.index.tolist(), 'imigrantes': brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.title('Imigração do Brasil para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.show()

# %%
argentina = df.loc['Argentina', anos]
argentina
# Out:
# 1980     368
# 1981     426
# 1982     626
# 1983     241
# 1984     237
# 1985     196
# 1986     213
# 1987     519
# 1988     374
# 1989     538
# 1990     678
# 1991     763
# 1992    1023
# 1993    1022
# 1994     366
# 1995     380
# 1996     396
# 1997     391
# 1998     349
# 1999     318
# 2000     427
# 2001     635
# 2002     865
# 2003    1745
# 2004    1591
# 2005    1153
# 2006     847
# 2007     620
# 2008     540
# 2009     467
# 2010     459
# 2011     278
# 2012     263
# 2013     282
# Name: Argentina, dtype: object

# %%
argentina_dict = {'ano': argentina.index.tolist(), 'imigrantes': argentina.values.tolist()}
dados_argentina = pd.DataFrame(argentina_dict)

# %%
dados_argentina
# Out:
#      ano  imigrantes
# 0   1980         368
# 1   1981         426
# 2   1982         626
# 3   1983         241
# 4   1984         237
# 5   1985         196
# 6   1986         213
# 7   1987         519
# 8   1988         374
# 9   1989         538
# 10  1990         678
# 11  1991         763
# 12  1992        1023
# 13  1993        1022
# 14  1994         366
# 15  1995         380
# 16  1996         396
# 17  1997         391
# 18  1998         349
# 19  1999         318
# 20  2000         427
# 21  2001         635
# 22  2002         865
# 23  2003        1745
# 24  2004        1591
# 25  2005        1153
# 26  2006         847
# 27  2007         620
# 28  2008         540
# 29  2009         467
# 30  2010         459
# 31  2011         278
# 32  2012         263
# 33  2013         282

# %%
dados_brasil_argentina = pd.DataFrame()
dados_brasil_argentina['ano'] = dados_brasil['ano']
dados_brasil_argentina['brasil'] = dados_brasil['imigrantes']
dados_brasil_argentina['argentina'] = dados_argentina['imigrantes']
dados_brasil_argentina
# Out:
#      ano  brasil  argentina
# 0   1980     211        368
# 1   1981     220        426
# 2   1982     192        626
# 3   1983     139        241
# 4   1984     145        237
# 5   1985     130        196
# 6   1986     205        213
# 7   1987     244        519
# 8   1988     394        374
# 9   1989     650        538
# 10  1990     650        678
# 11  1991     877        763
# 12  1992    1066       1023
# 13  1993     866       1022
# 14  1994     566        366
# 15  1995     572        380
# 16  1996     586        396
# 17  1997     591        391
# 18  1998     531        349
# 19  1999     626        318
# 20  2000     845        427
# 21  2001     847        635
# 22  2002     745        865
# 23  2003     839       1745
# 24  2004     917       1591
# 25  2005     969       1153
# 26  2006    1181        847
# 27  2007    1746        620
# 28  2008    2138        540
# 29  2009    2509        467
# 30  2010    2598        459
# 31  2011    1508        278
# ...

# %%
# prompt: quero gerar um gráfico com o plot dessa tabela de cima

plt.figure(figsize=(8, 4))
plt.plot(dados_brasil_argentina['ano'], dados_brasil_argentina['brasil'], label='Brasil')
plt.plot(dados_brasil_argentina['ano'], dados_brasil_argentina['argentina'], label='Argentina')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.title('Imigração para o Canadá (Brasil e Argentina)')
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(dados_brasil['ano'], dados_brasil[['imigrantes']], lw=3, color='g')
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot da Imigração do Brasil para o Canadá\n1980 a 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de Imigrantes')
axs[1].grid()

plt.show()

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
fig, axs = plt.subplots(2,2, figsize=(10, 6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Imigração dos Quatro Maiores Países da América do Sul para o Canadá\n1980 a 2013')

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
    ax.set_xlabel('Ano')
    ax.set_ylabel('Número de Imigrantes')

ymin = 0
ymax = 7000
for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)

plt.show()

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
df = pd.DataFrame(vendas_2022, index=lojas)

fig, axs = plt.subplots(2,2, figsize=(14,8))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle=('Relação de Vendas das Lojas A, B, C e D')

axs[0,0].plot(df.loc['A'])
axs[0,0].set_title('Loja A')

axs[0,1].plot(df.loc['B'])
axs[0,1].set_title('Loja B')

axs[1,0].plot(df.loc['C'])
axs[1,0].set_title('Loja C')

axs[1,1].plot(df.loc['D'])
axs[1,1].set_title('Loja D')

for ax in axs.flat:
    ax.set_xlabel('Mês')
    ax.set_ylabel('Número de Vendas')


ylim=0
ymax=400
for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)

plt.show()

# %%
df.head()
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')
america_sul = df.query('Região == "América do Sul"')
america_sul
# Out:
#           País                 Continente          Região  1980  1981  1982  \
# 7    Argentina  América Latina e o Caribe  América do Sul   368   426   626
# 21     Bolívia  América Latina e o Caribe  América do Sul    44    52    42
# 24      Brasil  América Latina e o Caribe  América do Sul   211   220   192
# 35       Chile  América Latina e o Caribe  América do Sul  1233  1069  1078
# 39    Colômbia  América Latina e o Caribe  América do Sul   266   326   360
# 54     Equador  América Latina e o Caribe  América do Sul   238   207   184
# 74      Guiana  América Latina e o Caribe  América do Sul  2334  2943  3575
# 134   Paraguai  América Latina e o Caribe  América do Sul    45    26    32
# 135       Peru  América Latina e o Caribe  América do Sul   317   456   401
# 165   Suriname  América Latina e o Caribe  América do Sul    15    10    21
# 186    Uruguai  América Latina e o Caribe  América do Sul   128   132   146
# ...

# %%
america_sul_sorted = america_sul.sort_values('Total', ascending=True)
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']


fig, ax = plt.subplots(figsize=(12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)

plt.show()

# %%
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')
df.head()
america_sul = df.query('Região == "América do Sul"')
america_sul_sorted = america_sul.sort_values('Total', ascending=True)


cores = []
for pais in america_sul_sorted.index:
    if pais == 'Brasil':
        cores.append('green')
    else:
          cores.append('silver')




fig, ax = plt.subplots(figsize=(12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrantes\npara o Canadá no período de 1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
    ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
df = pd.DataFrame(vendas_2022, index=lojas)

fig, axs = plt.subplots(2,2, figsize=(14,8))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle=('Relação de Vendas das Lojas A, B, C e D')

axs[0,0].plot(df.loc['A'], color='g', lw=3)
axs[0,0].set_title('Loja A')
axs[0,0].spines['top'].set_visible(False)
axs[0,0].spines['right'].set_visible(False)



axs[0,1].plot(df.loc['B'], color='pink', lw=3)
axs[0,1].set_title('Loja B')
axs[0,1].spines['top'].set_visible(False)
axs[0,1].spines['right'].set_visible(False)

axs[1,0].plot(df.loc['C'], color='blue', lw=3)
axs[1,0].set_title('Loja C')
axs[1,0].spines['top'].set_visible(False)
axs[1,0].spines['right'].set_visible(False)

axs[1,1].plot(df.loc['D'], color='orange', lw=3)
axs[1,1].set_title('Loja D')
axs[1,1].spines['top'].set_visible(False)
axs[1,1].spines['right'].set_visible(False)

for ax in axs.flat:
    ax.set_xlabel('Mês')
    ax.set_ylabel('Número de Vendas')


ylim=0
ymax=400
for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)

fig.savefig('dados_lojas.png', transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# # Data Visualization - Seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
top_10index= top_10.set_index('País')

# %%
top_10index
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x=top_10index.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h')

ax.set(title='Top 10 Países com Maior Número de Imigrantes para o Canadá\n1980 a 2013',
             xlabel='Número de Imigrantes',
             ylabel='')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h')

ax.set_title('Top 10 Países com Maior Número de Imigrantes para o Canadá\n1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')

plt.show()

# %%
def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)
    ax.set_title('Top 10 Países com Maior Número de Imigrantes para o Canadá\n1980 a 2013', loc='left', fontsize=16)
    ax.set_xlabel('Número de Imigrantes', fontsize=14)
    ax.set_ylabel('')

    plt.show()

# %%
gerar_grafico_paleta('Blues')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('Blues_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('rocket')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('coolwarm')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('crest_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('crest_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('crest_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('crest_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('crest_r')
# Out:
# <ipython-input-23-eb91ef496d83>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette=palette)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette='crest_r')

ax.set_title('Top 10 Países com Maior Número de Imigrantes para o Canadá\n1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')

sns.despine()

plt.show()
# Out:
# <ipython-input-34-eb2ddd41769d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10index.index, x='Total', orient='h', palette='crest_r')

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# # Data Visualization - Plotly

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá de 1980 a 2013')
fig.update_traces(line_color='green', line_width=4)
fig.update_layout(width=1000, height=500,
                  xaxis={'tickangle':-45},
                  font_family='Arial',
                  font_size=14,
                  font_color='grey',
                  title_font_size=22,
                  title_font_color='black',
                  xaxis_title='Ano',
                  yaxis_title='Número de Imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
america_sul
# Out:
#           País                 Continente          Região  1980  1981  1982  \
# 7    Argentina  América Latina e o Caribe  América do Sul   368   426   626
# 21     Bolívia  América Latina e o Caribe  América do Sul    44    52    42
# 24      Brasil  América Latina e o Caribe  América do Sul   211   220   192
# 35       Chile  América Latina e o Caribe  América do Sul  1233  1069  1078
# 39    Colômbia  América Latina e o Caribe  América do Sul   266   326   360
# 54     Equador  América Latina e o Caribe  América do Sul   238   207   184
# 74      Guiana  América Latina e o Caribe  América do Sul  2334  2943  3575
# 134   Paraguai  América Latina e o Caribe  América do Sul    45    26    32
# 135       Peru  América Latina e o Caribe  América do Sul   317   456   401
# 165   Suriname  América Latina e o Caribe  América do Sul    15    10    21
# 186    Uruguai  América Latina e o Caribe  América do Sul   128   132   146
# ...

# %%
america_sul.index
# Out:
# Index([7, 21, 24, 35, 39, 54, 74, 134, 135, 165, 186, 189], dtype='int64')

# %%
america_sul= america_sul.set_index('País')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
df_america_sul_clean = america_sul.drop(['Continente', 'Região', 'Total'], axis=1)

# %%
df_america_sul_clean
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# País                                                                   ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
# Bolívia      44    52    42    49    38    44    79   165    63    68  ...
# Brasil      211   220   192   139   145   130   205   244   394   650  ...
# Chile      1233  1069  1078   781   681   533   633  1454   990  1023  ...
# Colômbia    266   326   360   244   235   214   257   376   352   439  ...
# Equador     238   207   184   155   179   208   240   344   265   278  ...
# Guiana     2334  2943  3575  2650  1932  2299  3942  6174  2977  3270  ...
# Paraguai     45    26    32    40    48    36    34    72    53    48  ...
# Peru        317   456   401   241   306   328   628   843  1237  1667  ...
# Suriname     15    10    21    12     5    16     7    46    16    24  ...
# ...

# %%
america_sul_final = df_america_sul_clean.T

# %%
america_sul_final
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
# 1985        196       44     130    533       214      208    2299        36
# 1986        213       79     205    633       257      240    3942        34
# 1987        519      165     244   1454       376      344    6174        72
# 1988        374       63     394    990       352      265    2977        53
# 1989        538       68     650   1023       439      278    3270        48
# 1990        678       71     650   1286       614      552    2824        56
# ...

# %%
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País',
              title='Imigração dos Países da América do Sul para o Canadá de 1980 a 2013', markers=True)

fig.update_layout(
    xaxis={'tickangle':-45},
    xaxis_title='Ano',
    yaxis_title='Número de Imigrantes',
    font_family='Arial',
    font_size=14,
    font_color='grey',
    title_font_size=22,
    title_font_color='black',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('imigracao_america_sul.html')

# %%
dados_brasil['Ano'] = dados_brasil['ano'].astype(int)

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()

# %%
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Imigrantes', line=dict(width=4))
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objs as go

# Criando uma figura
fig = go.Figure()

# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Imigrantes', line=dict(width=4))),
# Definindo as configurações de layout
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil e Argentina para o Canadá no período de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1000,
    height=500
)

# Definir as configurações de animação
frames = [go.Frame(data=[go.Scatter(x=dados_brasil['ano'].iloc[:i+1], y=dados_brasil['imigrantes'].iloc[:i+1])]) for i in range(len(dados_brasil))]
fig.frames = frames

# Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Criando uma figura
fig = go.Figure()

# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Brasil', line=dict(width=4))),
fig.add_trace(
    go.Scatter(x=[dados_argentina['ano'].iloc[0]], y=[dados_argentina['imigrantes'].iloc[0]], mode='lines', name='Argentina', line=dict(width=4))
)
# Definindo as configurações de layout
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil e Argentina para o Canadá no período de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1000,
    height=500
)

# Definir as configurações de animação
frames = []
for i in range(len(dados_brasil)):
    frame_data = [
        go.Scatter(x=dados_brasil['ano'].iloc[:i+1], y=dados_brasil['imigrantes'].iloc[:i+1]),
        go.Scatter(x=dados_argentina['ano'].iloc[:i+1], y=dados_argentina['imigrantes'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Data Visualization - Hipóteses - Lâmpadas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados_idade_aposentadoria = pd.read_csv('/content/dados_idade_aposentadoria.csv')
dados_vida_lampada = pd.read_csv('/content/dados_vida_lampada.csv')
dados_alturas = pd.read_csv('/content/dados_alturas.csv')

# %%
plt.subplots(figsize=(20,5))
plt.subplot(131)
plt.title('Distribuição de Idade de Aposentadoria')
plt.xlabel('Idade Aposentadoria')
plt.ylabel('Frequência')
plt.hist(dados_idade_aposentadoria, bins=30, alpha=0.7, color='blue')

plt.subplot(132)
plt.hist(dados_vida_lampada, bins=30, alpha=0.7, color='purple')
plt.title('Tempo de Vida de uma Lâmpada')
plt.xlabel('Tempo de Vida (horas)')

plt.subplot(133)
plt.hist(dados_alturas, bins=30, alpha=0.7, color='green')
plt.title('Altura dos Funcionários')
plt.xlabel('Altura (cm)')

plt.show()

# %%
n =100 # tamanho da amostra
qnt =10000 # quantidade de amostras

def reamostragem_medias(dados, coluna, n, qnt):
  medias = [dados[coluna].sample(n, replace = True).mean()for _ in range(qnt)]
  return medias

# %%
media_idade = reamostragem_medias(dados_idade_aposentadoria, 'idade', n, qnt)
media_duracao = reamostragem_medias(dados_vida_lampada, 'duracao', n, qnt)
media_altura = reamostragem_medias(dados_alturas, 'alturas', n, qnt)

# %%
print("*****  Médias populacionais  *****")

print("idade", dados_idade_aposentadoria['idade'].mean())
print("duracao", dados_vida_lampada['duracao'].mean())
print("altura", dados_alturas['alturas'].mean())
# Out:
# *****  Médias populacionais  *****
# idade 62.70857142857143
# duracao 1731.8036029420002
# altura 169.52022

# %%
def Average(lst):
  return sum(lst) / len(lst)

print("*****  Médias amostrais  *****")

print("idade", Average(media_idade))
print("duracao", Average(media_duracao))
print("altura", Average(media_altura))
# Out:
# *****  Médias amostrais  *****
# idade 62.71424000000017
# duracao 1731.609263193006
# altura 169.53424353000042

# %%
plt.subplots(figsize=(15,5))
plt.subplot(131)
plt.title('Distribuição das Idades Médias de Aposentadoria')
plt.xlabel('Idade Média Aposentadoria')
plt.ylabel('Frequência')
plt.hist(media_idade, bins=30, alpha=0.7, color='blue')

plt.subplot(132)
plt.hist(media_duracao, bins=30, alpha=0.7, color='purple')
plt.title('Duração Média de uma Lâmpada')
plt.xlabel('Tempo de Vida Médio (horas)')

plt.subplot(133)
plt.hist(media_altura, bins=30, alpha=0.7, color='green')
plt.title('Altura Média dos Funcionários')
plt.xlabel('Altura Média (cm)')

plt.show()

# %%
media_nova_amostra = 1200 # nova média
dados_vida_lampada['duracao'].mean() # média original
# Out:
# np.float64(1731.8036029420002)

# %%
# Distância dessa Média

plt.hist(media_duracao, bins=30, alpha=0.7, color='purple')
plt.title('Duração média de uma Lâmpada')
plt.xlabel('Tempo de Vida Médio (horas)')
plt.annotate('.', xy=(media_nova_amostra, 0), xytext=(media_nova_amostra, 100), fontsize=8,
             arrowprops=dict(facecolor='green'))
plt.show()

# %%
duracao_amostras = pd.DataFrame({'medias_duracao': media_duracao})

# %%
media_das_medias = duracao_amostras['medias_duracao'].mean()
EP = duracao_amostras['medias_duracao'].std()

print("*****  Médias Amostrais  *****")
print("médias", media_das_medias)
print("Erro Padrão", EP)
# Out:
# *****  Médias Amostrais  *****
# médias 1731.6092631930132
# Erro Padrão 119.50389458563704

# %%
1731 - 3*EP
# Out:
# 1372.4883162430888

# %%
plt.hist(media_duracao, bins=30, alpha=0.7, color='purple')
plt.title('Duração média de uma Lâmpada')
plt.xlabel('Tempo de Vida Médio (horas)')
plt.axvline(media_das_medias, color = 'yellow')
plt.axvline(media_das_medias + 3*EP, color = 'green')
plt.axvline(media_das_medias - 3*EP, color = 'green')
plt.annotate('.', xy=(media_nova_amostra, 0), xytext=(media_nova_amostra, 100), fontsize=8,
             arrowprops=dict(facecolor='green'))
plt.show()

# %%
qnt_obs = duracao_amostras[(duracao_amostras > media_das_medias - 3*EP) &
                 (duracao_amostras < media_das_medias + 3*EP)]

# %%
qnt_obs.count()/duracao_amostras.count()*100
# Out:
# medias_duracao    99.7
# dtype: float64

# %%
qnt_obs2 = duracao_amostras[(duracao_amostras > media_das_medias - 1*EP) &
                 (duracao_amostras < media_das_medias + 1*EP)]

qnt_obs2.count()/duracao_amostras.count()*100
# Out:
# medias_duracao    68.65
# dtype: float64

# %%
qnt_obs3 = duracao_amostras[(duracao_amostras > media_das_medias - 2*EP) &
                 (duracao_amostras < media_das_medias + 2*EP)]

qnt_obs3.count()/duracao_amostras.count()*100
# Out:
# medias_duracao    95.36
# dtype: float64

# %%
from scipy import stats

# %%
dados_vida_lampada
confianca = 0.95

# %%
media = dados_vida_lampada['duracao'].mean()
desvio_padrao_amostra = dados_vida_lampada['duracao'].std()
tamanho_amostra = len(dados_vida_lampada)

# %%
intervalo_confianca = stats.norm.interval(confianca,
                                          loc=media,
                                          scale=desvio_padrao_amostra/np.sqrt(tamanho_amostra))

# %%
print("IC (95%):", intervalo_confianca)
# Out:
# IC (95%): (np.float64(1658.3741665835485), np.float64(1805.233039300452))

# %%
# Atividade TechTaste - Restaurante Delivery
# Conjunto de dados TechTaste
df_techtaste = pd.DataFrame({'avaliacoes': [38, 44, 33, 42, 47, 33, 36, 39, 42, 36, 39, 34, 42, 42, 36, 43, 31, 35, 36, 41, 42, 30, 25, 38, 47, 36, 32, 45, 44, 45, 37, 48, 37, 36, 44, 49, 31, 45, 45, 40, 36, 50, 38, 34, 36, 42, 46, 49, 36, 34, 38, 31, 53, 40, 57, 40, 36, 42, 26, 50, 32, 43, 35, 37, 42, 30, 36, 43, 40, 43, 44, 52, 37, 51, 35, 47, 40, 50, 37, 49]})

# %%
desvio_padrao_techtaste = df_techtaste['avaliacoes'].std()
EP_techtaste = desvio_padrao_techtaste/np.sqrt(len(df_techtaste))

# %%
plt.subplots(figsize=(15,5))
plt.subplot()
plt.title('Distribuição das Avaliações dos Clientes')
plt.xlabel('Avaliações')
plt.ylabel('Frequência')
plt.hist(df_techtaste, bins=30, alpha=0.7, color='blue')

plt.show()

# %%
confianca2 = 0.90

# %%
media_techtaste = df_techtaste['avaliacoes'].mean()
tamanho_amostra2 = len(df_techtaste)
intervalo_confianca_techtaste = stats.norm.interval(confianca2,
                                          loc=media_techtaste,
                                          scale=desvio_padrao_techtaste/np.sqrt(len(df_techtaste)))

print("IC (90%):", intervalo_confianca_techtaste)
# Out:
# IC (90%): (np.float64(38.84402439920928), np.float64(41.205975600790715))

# %%
tamanho_amostra2 = len(df_techtaste)
intervalo_confianca_techtaste = stats.norm.interval(confianca,
                                          loc=media_techtaste,
                                          scale=desvio_padrao_techtaste/np.sqrt(len(df_techtaste)))

print("IC (90%):", intervalo_confianca_techtaste)
# Out:
# IC (90%): (np.float64(38.617780776207844), np.float64(41.43221922379215))

# %%
n =100 # tamanho da amostra
qnt =10000 # quantidade de amostras

def reamostragem_medias2(dados, coluna, n, qnt):
  media_techtaste = [dados[coluna].sample(n, replace = True).mean()for _ in range(qnt)]
  return media_techtaste

media_techtaste = reamostragem_medias2(df_techtaste, 'avaliacoes', n, qnt)

def Average(lst):
  return sum(lst) / len(lst)

print("*****  Média amostral  *****")

print("avaliacoes", Average(media_techtaste))


plt.subplots(figsize=(15,5))
plt.subplot()
plt.title('Distribuição das Avaliações dos Clientes')
plt.xlabel('Avaliações')
plt.ylabel('Frequência')
plt.hist(media_techtaste, bins=30, alpha=0.7, color='blue')

plt.show()
# Out:
# *****  Média amostral  *****
# avaliacoes 40.03060300000013

# %%
media_techtaste = df_techtaste['avaliacoes'].mean()
tamanho_amostra2 = len(df_techtaste)
intervalo_confianca_techtaste = stats.norm.interval(confianca2,
                                          loc=media_techtaste,
                                          scale=desvio_padrao_techtaste/np.sqrt(len(df_techtaste)))

print("IC (90%):", intervalo_confianca_techtaste)
# Out:
# IC (90%): (np.float64(38.84402439920928), np.float64(41.205975600790715))

# %%
tamanho_amostra2 = len(df_techtaste)
intervalo_confianca_techtaste = stats.norm.interval(confianca,
                                          loc=media_techtaste,
                                          scale=desvio_padrao_techtaste/np.sqrt(len(df_techtaste)))

print("IC (90%):", intervalo_confianca_techtaste)
# Out:
# IC (90%): (np.float64(38.617780776207844), np.float64(41.43221922379215))

# %%
import seaborn as sns

sns.kdeplot(df_techtaste['avaliacoes'], linewidth=2, fill= True)

plt.xlabel('Avaliações')
plt.ylabel('Frequência')
plt.title('Distribuição suave TechTaste')
plt.show()
